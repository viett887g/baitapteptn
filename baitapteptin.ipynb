# %% [markdown]
# <a href="https://colab.research.google.com/github/viett887g/baitapteptn/blob/main/baitapteptin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1

# %%
f = open('test.txt', 'w+')
print("Hay nhap bat ky thu gi vao ")
with open('test.txt', 'w') as f:
    f.write(input())
f.close()
# Out:
# Hay nhap bat ky thu gi vao
# jfsufag

# %%
2

# %%
print("hay nhap ten tep tin ")
n = str(input())
f = open(n,'r')
print(f.read())
# Out:
# hay nhap ten tep tin
# test.txt
# abcdef

# %%
print("hay nhap ten tep tin ")
nba = str(input())
f = open(nba, 'w+')
print("Hay nhap bat ky thu gi vao ")
with open(nba, 'a') as f:
    f.write(input())
f.close()
# Out:
# hay nhap ten tep tin
# test.txt
# Hay nhap bat ky thu gi vao
# nacl

# %%
4

# %%
f = open(nba, 'r')
print(f.read())
f.close()
# Out:
# nacl

# %%
5

# %%
import random
lit = []
for i in range(0,999):
  lit.append(str(random.randint(-1000,1000)))
print(lit)
print("hay nhap ten tep tin ")
nba = str(input())
f = open(nba, 'w+')
with open(nba, 'w') as f:
    f.writelines(lit)
f.close()
# Out:
# ['614', '635', '-347', '631', '-774', '-996', '-265', '46', '496', '-505', '424', '-176', '794', '869', '892', '-9', '-988', '-413', '948', '557', '650', '702', '528', '226', '263', '-203', '780', '654', '207', '-588', '532', '-264', '716', '6', '-916', '92', '-773', '200', '-794', '-658', '379', '235', '-8', '236', '391', '-573', '117', '-938', '293', '259', '379', '-428', '-991', '-609', '987', '820', '-334', '928', '693', '-627', '-546', '-123', '-463', '544', '-692', '499', '-165', '-204', '55', '651', '-6', '914', '610', '-10', '75', '-965', '776', '416', '-281', '296', '-326', '-314', '464', '-16', '599', '-126', '765', '-902', '916', '-877', '573', '757', '969', '701', '-766', '-861', '863', '-968', '-461', '-608', '485', '201', '768', '429', '-526', '-128', '-182', '660', '-352', '-248', '-244', '-250', '-577', '-800', '503', '-549', '-672', '833', '-35', '-176', '157', '-78', '126', '373', '602', '355', '-494', '722', '-201', '108', '515', '-742', '214', '-544', '-290', '-24
# ...
